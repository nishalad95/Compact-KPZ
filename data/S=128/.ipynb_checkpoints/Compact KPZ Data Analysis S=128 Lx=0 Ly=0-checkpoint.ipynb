# %% [markdown]
# # Compact KPZ Data Analysis S=128 Lx=0 Ly=0

# %% [markdown]
# #### Nisha Lad

# %% [markdown]
# Calibration of KPZ - set $\lambda_x = 0.0, \lambda_y = 0.0$, Lattice size S = 128

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
I = 24
avgEnergy = [0] * I
avgNumVortices = [0] * I
avgEnergySquared = [0] * I
# 'temperature', pump power
CL = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.2, 3.3, 3.4, 3.45, 3.5, 3.55, 3.6, 3.65, 3.7, 3.8, 4.0, 4.5, 5.0, 5.5, 6.0, 6.5, 7.0]
np.savetxt("CL_S=128_Lx=0.0_Ly=0.0.txt", CL, delimiter=' ')
print(CL)
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.2, 3.3, 3.4, 3.45, 3.5, 3.55, 3.6, 3.65, 3.7, 3.8, 4.0, 4.5, 5.0, 5.5, 6.0, 6.5, 7.0]

# %%
def PlotGraphs(r, cl, N, cl_index, noise=True):
    R = r
    fig = plt.figure(figsize=(6, 5))
    if noise:
        stocAvg = 0.0
        stocAvg2 = 0.0
        stocVortex = 0.0
    for i in range(1,R+1):
        energy = np.loadtxt("Lx=0,Ly=0/CL_" + str(cl) + "/Energy_CL" + str(cl) + "_N" + str(N) + "_R" + str(i) + ".txt", dtype=float)
        iteration = np.arange(0, len(energy), 1)
        plt.plot(iteration, energy)
        if noise:
            stocAvg += energy[-1]
            stocAvg2 += energy[-1]**2
    if noise:
        stocAvg2 /= R
        stocAvg /= R
    plt.title("Energy as a function of time for a $128$x$128$ matrix, \n over " + str(R) + "\
    realizations, $C_l =" + str(cl) + "$, $N =" + str(N) + "$, $\lambda = 0$")
    plt.xlabel("time [T]")
    plt.ylabel("E")
    fig.savefig("Lx=0,Ly=0/Graphs/energyTimeCl=" + str(cl) + ".png", dpi=100)
    plt.show()

    fig = plt.figure(figsize=(6, 5))
    plt.xlabel("time [T]")
    plt.ylabel("Number of vortices")
    plt.title("Number of vortices as a function of time for a $128$x$128$ matrix, \n over " + str(R) + "\
    realizations, $C_l = " + str(cl) + "$, $N =" + str(N) + "$, $\lambda = 0$")

    for i in range(1,R+1):
        vortexNum = np.loadtxt("Lx=0,Ly=0/CL_" + str(cl) + "/VortexNum_CL" + str(cl) + "_N" + str(N) + "_R" + str(i) + ".txt", dtype=float)
        plt.plot(iteration, vortexNum)
        if noise:
            stocVortex += vortexNum[-1]
    fig.savefig("Lx=0,Ly=0/Graphs/vorticesTimeCl=" + str(cl) + ".png", dpi=100)
    if noise:
        stocVortex /= R
        avgEnergy[cl_index] = stocAvg
        avgNumVortices[cl_index] = stocVortex
        avgEnergySquared[cl_index] = stocAvg2
    elif cl_index == 0:
        avgEnergy[0] = energy[-1]
        avgNumVortices[0] = vortexNum[-1]
        avgEnergySquared[0] = energy[-1]**2

# %%
PlotGraphs(1, 0, 400, 0, False)

# %%
PlotGraphs(10, 0.5, 400, 1)

# %%
PlotGraphs(10, 1, 500, 2)

# %%
PlotGraphs(20, 1.5, 600, 3)

# %%
PlotGraphs(30, 2, 700, 4)

# %%
PlotGraphs(40, 2.5, 800, 5)

# %%
PlotGraphs(50, 3, 800, 6)

# %%
PlotGraphs(50, 3.2, 800, 7)

# %%
PlotGraphs(50, 3.3, 800, 8)

# %%
PlotGraphs(50, 3.4, 800, 9)

# %%
PlotGraphs(50, 3.45, 800, 10)

# %%
PlotGraphs(50, 3.5, 800, 11)

# %%
PlotGraphs(50, 3.55, 800, 12)

# %%
PlotGraphs(50, 3.6, 800, 13)

# %%
PlotGraphs(50, 3.65, 800, 14)

# %%
PlotGraphs(50, 3.7, 800, 15)

# %%
PlotGraphs(50, 3.8, 800, 16)

# %%
PlotGraphs(60, 4, 500, 17)

# %%
PlotGraphs(80, 4.5, 200, 18)

# %%
PlotGraphs(80, 5, 100, 19)

# %%
PlotGraphs(100, 5.5, 80, 20)

# %%
PlotGraphs(100, 6, 80, 21)

# %%
PlotGraphs(100, 6.5, 40, 22)

# %%
PlotGraphs(100, 7, 20, 23)

# %%
fig, ax = plt.subplots()
major_ticks = np.arange(0, 7.2, 0.5)
minor_ticks = np.arange(0, 7.0, 0.1)
ax.set_xticks(major_ticks, minor = False)
ax.set_xticks(minor_ticks, minor = True)
ax.plot(CL, avgEnergy, 'b.')
plt.title("Average Energy Density as a function of Noise \n for a 128x128 matrix $\lambda_x = 0, \lambda_y = 0$")
plt.xlabel("$C_l$")
plt.ylabel("$<E>/S^2$")
np.savetxt("energyDensityVsCL_S=128_Lx=0_Ly=0.txt", avgEnergy, delimiter=' ')
fig.savefig("Lx=0,Ly=0/Graphs/energyDensityCl.png", dpi=100)

# %%
# specific heat - discrete derivative
# dE/dT vs T = dE/dC_l vs C_l
dE = [0] * I
for i in range(0,I-1):
    dE[i] = (avgEnergy[i+1] - avgEnergy[i])/(CL[i+1] - CL[i])

fig, ax = plt.subplots()
major_ticks = np.arange(0, 7.2, 0.5)
minor_ticks = np.arange(0, 7.0, 0.1)
ax.set_xticks(major_ticks, minor = False)
ax.set_xticks(minor_ticks, minor = True)
ax.plot(CL, dE, 'b.')
plt.title("Specific Heat as a function of pump power \n for a 128x128 matrix $\lambda_x = 0, \lambda_y = 0$")
plt.xlabel("$C_l$")
plt.ylabel("$C_V$")
np.savetxt("specificHeatVsCL_S=128_Lx=0_Ly=0.txt", dE, delimiter=' ')
fig.savefig("Lx=0,Ly=0/Graphs/specificHeatCl.png", dpi=100)

# %%
# specific heat - discrete derivative
# variance of energy
Cv = [0] * I
for i in range(1,I-1):
    Cv[i] = (avgEnergySquared[i] - avgEnergy[i]**2)/CL[i]**2

fig = plt.figure(figsize=(6, 5))
plt.plot(CL, Cv)
plt.title("Specific Heat as a function of pump power \n for a $128x128$ matrix $\lambda_x = 0, \lambda_y = 0$")
plt.xlabel("$C_l$")
plt.ylabel("$C_V$")

# %%
fig, ax = plt.subplots()
major_ticks = np.arange(0, 7.2, 0.5)
minor_ticks = np.arange(0, 7.0, 0.1)
ax.set_xticks(major_ticks, minor = False)
ax.set_xticks(minor_ticks, minor = True)
ax.plot(CL, avgNumVortices, 'b.')
plt.title("Average Number of Vortices plus Antivortices as a \n"
          "function of Noise for a 128x128 matrix $\lambda_x = 0, \lambda_y = 0$")
plt.xlabel("$C_l$")
plt.ylabel("$Vortices + Antivortices$")
np.savetxt("numOfVorticesVsCL_S=128_Lx=0_Ly=0.txt", dE, delimiter=' ')
fig.savefig("Lx=0,Ly=0/Graphs/totalVorticesCl.png", dpi=100)
