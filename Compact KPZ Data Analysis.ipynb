# %% [markdown]
# # Compact KPZ Data Analysis

# %% [markdown]
# #### Nisha Lad

# %% [markdown]
# Calibration of KPZ - set lambda = 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
avgEnergy = [0] * 11

# %%
energy = np.loadtxt("CL_0/Energy_CL0_N100_R1.txt", dtype=float)
iteration = np.arange(0, len(energy), 1)
fig = plt.figure(figsize=(5, 3))
plt.plot(iteration, energy)
plt.title("Average energy as a function of time for a \n $64$x$64$ matrix, $C_l = 0.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
plt.show()
# only one unique realisation for a particular initial state, due to zero noise

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
vortexNum = np.loadtxt("CL_0/VortexNum_CL0_N100_R1.txt", dtype=float)
plt.plot(iteration, vortexNum)
avgEnergy[0] = energy[len(energy) - 1]

# %%
R = 5
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,5):
    energy = np.loadtxt("CL_0.5/Energy_CL0.5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, len(energy), 1)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) - 1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over five \
realizations, $C_l = 0.5$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 5 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,5):
    vortexNum = np.loadtxt("CL_0.5/VortexNum_CL0.5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[1] = stocAvg

# %%
R = 5
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,5):
    energy = np.loadtxt("CL_1/Energy_CL1_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over five \
realizations, $C_l = 1.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 5 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,5):
    vortexNum = np.loadtxt("CL_1/VortexNum_CL1_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[2] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_1.5/Energy_CL1.5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 1.5$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_1.5/VortexNum_CL1.5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)
avgEnergy[3] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_2/Energy_CL2_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 2.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_2/VortexNum_CL2_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[4] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_2.5/Energy_CL2.5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 2.5$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_2.5/VortexNum_CL2.5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)
avgEnergy[5] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_3/Energy_CL3_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 3.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_3/VortexNum_CL3_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[6] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_3.5/Energy_CL3.5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 3.5$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_3.5/VortexNum_CL3.5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)


avgEnergy[7] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_4/Energy_CL4_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 4.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_4/VortexNum_CL4_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[8] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_4.5/Energy_CL4.5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 4.5$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
#10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_4.5/VortexNum_CL4.5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[9] = stocAvg

# %%
R = 10
fig = plt.figure(figsize=(5, 3))
stocAvg = 0.0
for i in range(1,10):
    energy = np.loadtxt("CL_5/Energy_CL5_N100_R" + str(i) + ".txt", dtype=float)
    iteration = np.arange(0, 0.05*len(energy), 0.05)
    plt.plot(iteration, energy)
    stocAvg += energy[len(energy) -1]
stocAvg /= R
plt.title("Average energy as a function of time for a $64$x$64$ matrix, \n over ten \
realizations, $C_l = 5.0$, $N = 100$, $\lambda = 0$")
plt.xlabel("time [T]")
plt.ylabel("E")
# 10 realizations
plt.show()

fig = plt.figure(figsize=(5, 3))
plt.xlabel("time [T]")
plt.ylabel("Number of vortices")
for i in range(1,10):
    vortexNum = np.loadtxt("CL_5/VortexNum_CL5_N100_R" + str(i) + ".txt", dtype=float)
    plt.plot(iteration, vortexNum)

avgEnergy[10] = stocAvg

# %%
CL = np.arange(0.0, 5.5, 0.5) # 'temperature', pump power
print(CL)
print(avgEnergy)
fig = plt.figure(figsize=(5, 3))
plt.plot(CL, avgEnergy)
plt.title("Average Energy as a function of Noise")
plt.xlabel("$C_l$")
plt.ylabel("<E>")
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5. ]
# [-3.5466099999999998, -2.853812, -2.837774, -3.1485050000000001, -3.0981010000000002, -3.0326440000000003, -2.9566089999999998, -2.8588629999999999, -2.7408120000000005, -2.598617, -2.4293089999999999]

# %%
# specific heat
# dE/dT vs T = dE/dC_l vs C_l
print(avgEnergy)
print(len(avgEnergy))
dE = [0] * 10
for i in range(0,10):
  dE[i] = avgEnergy[i+1] - avgEnergy[i]  

dC_l = np.arange(0.25, 5.0, 0.5)
print(dC_l)
    
fig = plt.figure(figsize=(5, 3))
plt.plot(dC_l, dE)
plt.title("Specific Heat as a function of pump power ")
plt.xlabel("$C_l$")
plt.ylabel("$C_V$")
# Out:
# [-3.5466099999999998, -2.853812, -2.837774, -3.1485050000000001, -3.0981010000000002, -3.0326440000000003, -2.9566089999999998, -2.8588629999999999, -2.7408120000000005, -2.598617, -2.4293089999999999]
# 11
# [ 0.25  0.75  1.25  1.75  2.25  2.75  3.25  3.75  4.25  4.75]
